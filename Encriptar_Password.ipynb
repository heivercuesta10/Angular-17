# %% [markdown]
# # **Angular 17**

# %% [markdown]
# ![Angular17_.png](attachment:Angular17_.png)

# %% [markdown]
# # **Encriptar password para utilizar en FrontEnd**

# %% [markdown]
# # **Herramientas**

# %% [markdown]
# 1. Node JS
# 2. npm

# %% [markdown]
# # **Procedimiento**

# %% [markdown]
# 1. Crear un proyecto en Node
# 2.	Instalar las librerias:
#
#    a.	npm init
#    b.	npm install express mysql body-parser --save
#    c.	npm install md5
#
# 3.	Crear archivo index.js
# 4.	Importar las librerías

# %% [markdown]
# Incluir el siguiente código al archivo index.js para ver la funcionalidad:

# %%
const express = require('express')
const mysql = require('mysql2')
const bodyParser = require('body-parser')
// npm install md5
const md5 = require('md5')

# %% [markdown]
# 5.	Cuando recibas los datos que envias al backen, es decir que llegan del frontend debes aplicar el método que permite encriptar los valores de la variable ejemplo:

# %%
const express = require('express')
const mysql = require('mysql2')
const bodyParser = require('body-parser')
// npm install md5
const md5 = require('md5')

const clave = "heiver";

console.log(clave)

console.log(md5(clave))
